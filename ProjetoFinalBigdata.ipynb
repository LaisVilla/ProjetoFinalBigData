# %% [markdown]
# #Importando a biblioteca do pandas

# %%
import pandas as pd

# %% [markdown]
# #Importando o arquivo excel/Dataset

# %%
pip install openpyx
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting openpyxl
# ...
#      -------------------------------------- 250.0/250.0 kB 5.1 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
Df = pd.read_excel('Planilha_Operacoes_Vitoria.xlsx')

# %% [markdown]
# #Para executar o dataset

# %%
nomeDataframe
# Out:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4  \
# 0                   NaN        NaN        NaN        NaN          NaN
# 1                   NaN        NaN        NaN        NaN          NaN
# 2                   NaN        NaN        NaN        NaN          NaN
# 3                  Data     Origem    Destino       Peso  Valor Frete
# 4   2022-01-06 00:00:00    VITÓRIA  CARIACICA      97.27          820
# ..                  ...        ...        ...        ...          ...
# 64  2022-10-26 00:00:00    VITÓRIA  CARIACICA     414.43         1040
# 65  2022-10-26 00:00:00    VITÓRIA  CARIACICA    1536.63         1040
# 66  2022-11-01 00:00:00    VITÓRIA  CARIACICA     434.09         1040
# 67  2022-11-08 00:00:00    VITÓRIA  CARIACICA       1641         1040
# 68                Total        NaN        NaN  51324.332        65240
#
#             Unnamed: 5
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3   Transit Time / hrs
# ...

# %% [markdown]
# #Exibir primeiras linhas do dataset

# %%
Df.head(60)
# Out:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4  \
# 0                   NaN        NaN        NaN        NaN          NaN
# 1                   NaN        NaN        NaN        NaN          NaN
# 2                   NaN        NaN        NaN        NaN          NaN
# 3                  Data     Origem    Destino       Peso  Valor Frete
# 4   2022-01-06 00:00:00    VITÓRIA  CARIACICA      97.27          820
# 5   2022-01-11 00:00:00    VITÓRIA  CARIACICA        116          820
# 6   2022-01-12 00:00:00    VITÓRIA  CARIACICA          5          820
# 7   2022-01-14 00:00:00    VITÓRIA  CARIACICA     230.24          820
# 8   2022-01-21 00:00:00    VITÓRIA  CARIACICA       3.74          820
# 9   2022-01-25 00:00:00    VITÓRIA  CARIACICA     846.32          820
# 10  2022-02-01 00:00:00    VITÓRIA  CARIACICA     412.82         1040
# 11  2022-02-01 00:00:00    VITÓRIA  CARIACICA    1455.79         1040
# ...

# %% [markdown]
# #Informações gerais do dataset

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  66 non-null     object
#  1   Unnamed: 1  65 non-null     object
#  2   Unnamed: 2  65 non-null     object
#  3   Unnamed: 3  66 non-null     object
#  4   Unnamed: 4  66 non-null     object
#  5   Unnamed: 5  66 non-null     object
# dtypes: object(6)
# memory usage: 3.4+ KB

# %%
Df.shape
# Out:
# (69, 6)
